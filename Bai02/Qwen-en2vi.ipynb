# %%
# ============================================================================
# CELL 1: Cài đặt thư viện cần thiết
# ============================================================================
import subprocess
import sys

# Cài đặt các packages chính
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q", "-U",
    "transformers>=4.51.0", "accelerate>=1.0.0", "trl>=0.9.6", "datasets>=2.18.0"
])

# Cài đặt Unsloth và bitsandbytes
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q",
    "unsloth", "bitsandbytes"
])

print("✓ Đã cài đặt các thư viện cần thiết")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 125.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.4/517.4 kB 35.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 44.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 100.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pylibcudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# cudf-polars-cu12 25.6.0 requires pylibcudf-cu12==25.6.*, but you have pylibcudf-cu12 25.2.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.9/373.9 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 34.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.3/289.3 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.4/170.4 MB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 48.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 32.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 120.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.6/180.6 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 108.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 104.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.9/219.9 kB 14.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# s3fs 2025.3.0 requires fsspec==2025.3.0.*, but you have fsspec 2025.9.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.9.1 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# ✓ Đã cài đặt các thư viện cần thiết

# %%
# ============================================================================
# CELL 2: Cấu hình và load mô hình Qwen3 1.7B với Unsloth (4-bit quantization)
# ============================================================================

import os
from unsloth import FastLanguageModel
import torch

# === Cấu hình đường dẫn dataset MedicalDataset_VLSP ===
# Tự động tìm dataset trên Kaggle
dataset_paths = [
    "/kaggle/input/medicaldataset-vlsp/MedicalDataset_VLSP",
    "/kaggle/input/medicaldataset-vlsp",
    "MedicalDataset_VLSP",
    "./MedicalDataset_VLSP"
]

DATA_ROOT = None
for path in dataset_paths:
    train_en_file = os.path.join(path, "train.en.txt")
    if os.path.exists(path) and os.path.exists(train_en_file):
        DATA_ROOT = path
        print(f"✓ Tìm thấy dataset tại: {DATA_ROOT}")
        break

if DATA_ROOT is None:
    raise FileNotFoundError(
        "Không tìm thấy dataset MedicalDataset_VLSP!\n"
        "Đã thử các đường dẫn:\n" + "\n".join(f"  - {p}" for p in dataset_paths)
    )

TRAIN_EN_FILE = os.path.join(DATA_ROOT, "train.en.txt")
TRAIN_VI_FILE = os.path.join(DATA_ROOT, "train.vi.txt")

# Cấu hình số lượng samples (None = dùng tất cả)
LIMIT_SAMPLES = None  # Có thể set số nhỏ (vd: 20000) để test nhanh

# === Cấu hình mô hình ===
BASE_MODEL = "unsloth/Qwen3-1.7B-unsloth-bnb-4bit"
MAX_SEQUENCE_LENGTH = 2048
RANDOM_SEED = 3407

# Set random seed để đảm bảo reproducibility
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(RANDOM_SEED)

print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# Load Qwen3 1.7B với 4-bit quantization qua Unsloth
print(f"Đang load mô hình: {BASE_MODEL}")
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=BASE_MODEL,
    max_seq_length=MAX_SEQUENCE_LENGTH,
    load_in_4bit=True,      # Sử dụng QLoRA 4-bit để tiết kiệm memory
    load_in_8bit=False,
    full_finetuning=False, # Chỉ fine-tune với LoRA, không full fine-tune
    # token="hf_...",      # Thêm HuggingFace token nếu model là gated
)

print("✓ Đã load mô hình thành công")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-12-16 12:37:28.644993: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765888648.819175      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765888648.868024      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ✓ Tìm thấy dataset tại: /kaggle/input/medicaldataset-vlsp/MedicalDataset_VLSP
# CUDA available: True
# GPU: Tesla T4
# Đang load mô hình: unsloth/Qwen3-1.7B-unsloth-bnb-4bit
# ==((====))==  Unsloth 2025.12.5: Fast Qwen3 patching. Transformers: 4.57.3.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/1.41G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# ✓ Đã load mô hình thành công

# %%
# ============================================================================
# CELL 3: Cấu hình LoRA theo API Unsloth
# ============================================================================

print("Đang cấu hình LoRA...")

model = FastLanguageModel.get_peft_model(
    model,
    r=32,  # LoRA rank (theo khuyến nghị của Unsloth)
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha=32,
    lora_dropout=0.0,
    bias="none",
    use_gradient_checkpointing="unsloth",  # Sử dụng gradient checkpointing của Unsloth
    random_state=RANDOM_SEED,
    use_rslora=False,
    loftq_config=None,
)

# Kiểm tra device của model
first_param = next(model.parameters())
print(f"✓ Model device: {first_param.device}")
print("✓ LoRA đã được cấu hình")
# Out:
# Đang cấu hình LoRA...
# Unsloth 2025.12.5 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.
# ✓ Model device: cuda:0
# ✓ LoRA đã được cấu hình

# %%
# ============================================================================
# CELL 4: Load dữ liệu song ngữ và chuyển đổi sang format chat
# ============================================================================

from datasets import Dataset
import pandas as pd

def load_bilingual_data(en_file, vi_file, max_samples=None):
    """Load dữ liệu song ngữ từ file EN và VI"""
    with open(en_file, "r", encoding="utf-8") as f:
        english_lines = [line.rstrip("\n") for line in f]
    
    with open(vi_file, "r", encoding="utf-8") as f:
        vietnamese_lines = [line.rstrip("\n") for line in f]

    if len(english_lines) != len(vietnamese_lines):
        raise ValueError(
            f"Số dòng không khớp! EN: {len(english_lines)}, VI: {len(vietnamese_lines)}"
        )

    total = len(english_lines)
    if max_samples is not None and max_samples > 0:
        total = min(total, max_samples)

    english_lines = english_lines[:total]
    vietnamese_lines = vietnamese_lines[:total]

    print(f"✓ Đã load {total} cặp dữ liệu song ngữ (EN -> VI)")
    return english_lines, vietnamese_lines

# Load dữ liệu training
english_sentences, vietnamese_sentences = load_bilingual_data(
    TRAIN_EN_FILE, TRAIN_VI_FILE, LIMIT_SAMPLES
)

# Định nghĩa system prompt cho task dịch máy
TRANSLATION_SYSTEM_PROMPT = (
    "Bạn là hệ thống dịch máy chuyên nghiệp, dịch từ tiếng Anh sang tiếng Việt "
    "trong lĩnh vực y học / y sinh. Luôn giữ đúng ý nghĩa, thuật ngữ y khoa và "
    "không thêm bất kỳ giải thích hay nội dung phụ nào."
)

def create_chat_format(english_text, vietnamese_text):
    """Tạo format chat cho một cặp câu dịch"""
    # Mỗi sample là một đoạn hội thoại với system, user và assistant
    conversation = [
        {"role": "system", "content": TRANSLATION_SYSTEM_PROMPT},
        {"role": "user", "content": english_text},      # Câu nguồn (tiếng Anh)
        {"role": "assistant", "content": vietnamese_text},  # Câu đích (tiếng Việt)
    ]
    
    # Áp dụng chat template của Qwen3 (tắt thinking mode cho task MT)
    formatted_text = tokenizer.apply_chat_template(
        conversation,
        tokenize=False,
        add_generation_prompt=False,
        enable_thinking=False,  # Tắt thinking mode cho translation task
    )
    return formatted_text

# Tạo dataset từ các cặp câu
training_texts = [
    create_chat_format(en, vi)
    for en, vi in zip(english_sentences, vietnamese_sentences)
]

# Chuyển đổi sang Dataset format
dataframe = pd.DataFrame({"text": training_texts})
training_dataset = Dataset.from_pandas(dataframe)
training_dataset = training_dataset.shuffle(seed=RANDOM_SEED)

# Hiển thị sample đầu tiên
sample_text = training_dataset[0]["text"]
print(f"\nSample text (500 ký tự đầu):\n{sample_text[:500]}")
print(f"\n✓ Tổng số mẫu training: {len(training_dataset)}")
# Out:
# ✓ Đã load 500000 cặp dữ liệu song ngữ (EN -> VI)
#
# Sample text (500 ký tự đầu):
# <|im_start|>system
# Bạn là hệ thống dịch máy chuyên nghiệp, dịch từ tiếng Anh sang tiếng Việt trong lĩnh vực y học / y sinh. Luôn giữ đúng ý nghĩa, thuật ngữ y khoa và không thêm bất kỳ giải thích hay nội dung phụ nào.<|im_end|>
# <|im_start|>user
# Aneurysms are classified as Fusiform: Circumferential widening of the artery Saccular: Localized, typically asymmetric, outpouchings of the artery wall Layered (laminated) thrombus may line the walls of either type as the result of alterations in flow wit
#
# ✓ Tổng số mẫu training: 500000

# %%
# ============================================================================
# CELL 5: Fine-tune mô hình Qwen3 bằng SFTTrainer (theo style Unsloth)
# ============================================================================

from trl import SFTTrainer, SFTConfig

print("\nĐang khởi tạo trainer...")

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=training_dataset,
    eval_dataset=None,  # Có thể thêm validation set sau nếu cần
    args=SFTConfig(
        dataset_text_field="text",  # Tên cột chứa text để train
        per_device_train_batch_size=2,  # Batch size phù hợp với T4 16GB
        gradient_accumulation_steps=4,  # Effective batch size = 2 * 4 = 8
        warmup_steps=5,
        # num_train_epochs=1,  # Có thể set theo epoch nếu muốn
        max_steps=4000,  # Số steps để train (có thể điều chỉnh)
        learning_rate=2e-4,  # Learning rate theo khuyến nghị Unsloth
        logging_steps=10,
        optim="adamw_8bit",  # Optimizer 8-bit để tiết kiệm memory
        weight_decay=0.001,
        lr_scheduler_type="linear",
        seed=RANDOM_SEED,
        report_to="none",  # Tắt logging lên WandB/TensorBoard
    ),
)

print("✓ Trainer đã được khởi tạo")
print("\n" + "="*60)
print("BẮT ĐẦU TRAINING")
print("="*60)

training_stats = trainer.train()

print("\n" + "="*60)
print("TRAINING HOÀN TẤT")
print("="*60)
print(f"✓ Tổng số global steps: {trainer.state.global_step}")
# Out:
# Đang khởi tạo trainer...
# Unsloth: Tokenizing ["text"] (num_proc=8):   0%|          | 0/500000 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.
# ✓ Trainer đã được khởi tạo
#
# ============================================================
# BẮT ĐẦU TRAINING
# ============================================================
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 500,000 | Num Epochs = 1 | Total steps = 4,000
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 34,865,152 of 1,755,440,128 (1.99% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='4000' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4000/4000 1:51:58, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.971300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.265600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.143900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.086800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.114400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.024200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.052600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.022500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.026300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.068100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.976700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.030500</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.048200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.995300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.049100</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.984600</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.942600</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.985700</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.940000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.057100</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.997200</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.992000</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.069800</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.022800</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.003500</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.942200</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.041500</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.015900</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.009400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.019900</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.922900</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.980900</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.003100</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.974500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.025600</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.976400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.012200</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.979500</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.926000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.965000</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.000600</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.994900</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.968800</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.963300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.964600</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.984600</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.009900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.022400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.929300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.070000</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.961600</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.967800</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.988900</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.953900</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.979700</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.969900</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.960100</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.994800</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.949300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.963700</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>1.045100</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.973600</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.985200</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.953900</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.915200</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.973000</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.921900</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.911500</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.934200</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.948500</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.947100</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>1.011300</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.913700</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.955200</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.899000</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.943500</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.986600</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.943900</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.915800</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.983000</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.917500</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.920100</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.980100</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.916700</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1.007900</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.953100</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.922900</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.979700</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.915400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.936200</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.971200</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.904600</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.915500</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.908200</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.910500</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.924700</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.944800</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.928600</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.880300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.910400</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.927200</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.927500</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.968000</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.943800</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.966700</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.957800</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.880200</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.948800</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.964500</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.022400</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.984500</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.954400</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.946200</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.896900</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.929500</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.936800</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.978000</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.951000</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.915900</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.963300</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.901000</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.913300</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.942500</td>
#     </tr>
#     <tr>
#       <td>1
# ============================================================
# TRAINING HOÀN TẤT
# ============================================================
# ✓ Tổng số global steps: 4000

# %%
# ============================================================================
# CELL 6: Lưu LoRA adapter và tokenizer
# ============================================================================

SAVE_DIR = "qwen3-1_7b-en-vi-mt"  # Thư mục lưu kết quả
os.makedirs(SAVE_DIR, exist_ok=True)

lora_adapter_path = os.path.join(SAVE_DIR, "lora_adapter")
tokenizer_path = os.path.join(SAVE_DIR, "tokenizer")

model.save_pretrained(lora_adapter_path)
tokenizer.save_pretrained(tokenizer_path)

print(f"\n✓ Đã lưu LoRA adapter tại: {lora_adapter_path}")
print(f"✓ Đã lưu tokenizer tại: {tokenizer_path}")
# Out:
# ✓ Đã lưu LoRA adapter tại: qwen3-1_7b-en-vi-mt/lora_adapter
# ✓ Đã lưu tokenizer tại: qwen3-1_7b-en-vi-mt/tokenizer

# %%
# ============================================================================
# CELL 7: Test nhanh dịch với mô hình đã fine-tune
# ============================================================================

from unsloth import FastLanguageModel
import torch

# Chuyển model sang inference mode
FastLanguageModel.for_inference(model)

def translate_english_to_vietnamese(english_text, max_new_tokens=128):
    """Dịch một câu tiếng Anh sang tiếng Việt"""
    chat_messages = [
        {"role": "system", "content": TRANSLATION_SYSTEM_PROMPT},
        {"role": "user", "content": english_text},
    ]
    
    # Tạo prompt với generation prompt
    prompt_text = tokenizer.apply_chat_template(
        chat_messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False,
    )
    
    # Tokenize và chuyển sang device
    inputs = tokenizer(prompt_text, return_tensors="pt").to(model.device)

    # Generate translation
    with torch.no_grad():
        generated = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,  # Greedy decoding cho translation
        )

    # Extract phần được generate (bỏ qua phần prompt)
    prompt_length = inputs["input_ids"].shape[1]
    generated_ids = generated[0][prompt_length:]
    
    # Decode và trả về
    translation = tokenizer.decode(generated_ids, skip_special_tokens=True).strip()
    return translation

# Test với 3 câu đầu
print("\n" + "="*60)
print("TEST DỊCH (3 câu đầu)")
print("="*60)
for idx in range(3):
    source = english_sentences[idx]
    reference = vietnamese_sentences[idx]
    prediction = translate_english_to_vietnamese(source)
    
    print(f"\n[Sample {idx+1}]")
    print(f"EN  : {source}")
    print(f"REF : {reference}")
    print(f"PRED: {prediction}")
    print("-" * 80)
# Out:
# ============================================================
# TEST DỊCH (3 câu đầu)
# ============================================================
#
# [Sample 1]
# EN  : To evaluate clinical, subclinical symptoms of patients with otitis media with effusion and V.a at otorhinolaryngology department – Thai Nguyen national hospital
# REF : Nghiên cứu đặc điểm lâm sàng, cận lâm sàng bệnh nhân viêm tai ứ dịch trên viêm V.A tại Khoa Tai mũi họng - Bệnh viện Trung ương Thái Nguyên
# PRED: Đánh giá lâm sàng, cận lâm sàng của bệnh nhân viêm tai giữa có tràn dịch và V. a tại khoa tai mũi họng – Bệnh viện Trung ương Thái Nguyên
# --------------------------------------------------------------------------------
#
# [Sample 2]
# EN  : Evaluate clinical, subclinical symptoms of patients with otittis media effusion and V a at otorhinolaryngology department - Thai Nguyên National Hospital.
# REF : Đánh giá đặc điểm lâm sàng, cận lâm sàng bệnh nhân viêm tai ứ dịch trên viêm V.a tại Khoa Tai mũi họng - Bệnh viện Trung ương Thái Nguyên.
# PRED: Đánh giá triệu chứng lâm sàng, cận lâm sàng của bệnh nhân tràn dịch tai giữa và viêm mũi xoang V a tại khoa Tai Mũi Họng - Bệnh viện Trung ương Thái Nguyên.
# --------------------------------------------------------------------------------
#
# [Sample 3]
# EN  : There was a relation between vasodilatation and vaginal dysfunction.
# REF : Có sự liên quan giữa độ quá phát V.a với mức độ rối loạn chức năng vòi nhĩ.
# PRED: Có mối liên quan giữa giãn mạch và rối loạn chức năng âm đạo.
# --------------------------------------------------------------------------------

# %%
# ============================================================================
# CELL 8: Cài đặt thư viện đánh giá và tính SacreBLEU trên public_test
# ============================================================================

import subprocess
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q",
    "sacrebleu", "evaluate"
])

import os
import torch
from tqdm.auto import tqdm
import evaluate
from unsloth import FastLanguageModel

# === Đường dẫn test set ===
TEST_EN_FILE = os.path.join(DATA_ROOT, "public_test.en.txt")
TEST_VI_FILE = os.path.join(DATA_ROOT, "public_test.vi.txt")

# Giới hạn số lượng test samples (None = dùng tất cả)
MAX_TEST = None

# === Đọc test set ===
with open(TEST_EN_FILE, "r", encoding="utf-8") as f:
    test_english = [line.rstrip("\n") for line in f]

# Kiểm tra xem có file reference không
has_reference = os.path.exists(TEST_VI_FILE)
test_vietnamese = []
if has_reference:
    with open(TEST_VI_FILE, "r", encoding="utf-8") as f:
        test_vietnamese = [line.rstrip("\n") for line in f]
    if len(test_english) != len(test_vietnamese):
        raise ValueError(
            f"Số dòng test không khớp! EN: {len(test_english)}, VI: {len(test_vietnamese)}"
        )

test_count = len(test_english)
if MAX_TEST is not None and MAX_TEST > 0:
    test_count = min(test_count, MAX_TEST)
    test_english = test_english[:test_count]
    if has_reference:
        test_vietnamese = test_vietnamese[:test_count]

print(f"\n✓ Số mẫu test: {test_count}")
if has_reference:
    print("✓ Có file reference để tính BLEU")
else:
    print("⚠ Không có file reference, chỉ sinh predictions")

# Chuyển model sang inference mode
device = next(model.parameters()).device
FastLanguageModel.for_inference(model)

def translate_batch_en_to_vi(batch_english, max_new_tokens=256):
    """Dịch một batch câu tiếng Anh sang tiếng Việt"""
    prompts_list = []
    for en_text in batch_english:
        messages = [
            {"role": "system", "content": TRANSLATION_SYSTEM_PROMPT},
            {"role": "user", "content": en_text},
        ]
        chat_prompt = tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=False,  # Tắt thinking mode cho translation
        )
        prompts_list.append(chat_prompt)

    # Tokenize batch
    tokenized_inputs = tokenizer(
        prompts_list,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=MAX_SEQUENCE_LENGTH,
    ).to(device)

    input_ids = tokenized_inputs["input_ids"]
    attention_mask = tokenized_inputs["attention_mask"]
    actual_lengths = attention_mask.sum(dim=1)  # Độ dài thực của mỗi câu (không tính padding)

    # Generate translations
    with torch.no_grad():
        generated_outputs = model.generate(
            **tokenized_inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,  # Greedy decoding
        )

    # Extract translations (bỏ phần prompt)
    translations = []
    for i in range(generated_outputs.size(0)):
        generated_part = generated_outputs[i, actual_lengths[i]:]
        translated_text = tokenizer.decode(generated_part, skip_special_tokens=True).strip()
        translations.append(translated_text)
    
    return translations

# === Sinh predictions trên test set ===
INFERENCE_BATCH_SIZE = 4  # Có thể tăng lên 8/16 nếu GPU đủ mạnh

predictions = []
references = []
for start_idx in tqdm(range(0, test_count, INFERENCE_BATCH_SIZE), desc="Dịch test set"):
    end_idx = min(start_idx + INFERENCE_BATCH_SIZE, test_count)
    batch_en = test_english[start_idx:end_idx]
    batch_ref = test_vietnamese[start_idx:end_idx] if has_reference else []

    batch_predictions = translate_batch_en_to_vi(batch_en)
    predictions.extend(batch_predictions)
    if has_reference:
        references.extend(batch_ref)

# Hiển thị 3 ví dụ đầu
print("\n" + "="*60)
print("VÍ DỤ 3 CÂU ĐẦU")
print("="*60)
for i in range(min(3, test_count)):
    print(f"\n[Test {i+1}]")
    print(f"EN  : {test_english[i]}")
    if has_reference:
        print(f"REF : {references[i]}")
    print(f"PRED: {predictions[i]}")
    print("-" * 80)

# === Tính SacreBLEU (chỉ nếu có reference) ===
if has_reference:
    bleu_metric = evaluate.load("sacrebleu")
    bleu_results = bleu_metric.compute(
        predictions=predictions,
        references=[[ref] for ref in references],  # SacreBLEU cần format list[list[str]]
    )
    print("\n" + "="*60)
    print("KẾT QUẢ SACREBLEU")
    print("="*60)
    print(f"SacreBLEU score: {bleu_results['score']:.2f}")
    print(f"Chi tiết: {bleu_results}")
else:
    print("\n⚠ Không có reference để tính BLEU, chỉ sinh predictions")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.6 MB/s eta 0:00:00
#
# ✓ Số mẫu test: 3000
# ✓ Có file reference để tính BLEU
# Dịch test set:   0%|          | 0/750 [00:00<?, ?it/s]
# ============================================================
# VÍ DỤ 3 CÂU ĐẦU
# ============================================================
#
# [Test 1]
# EN  : Knowledge, practices in public health service utilization among health insurance card’s holders and influencing factors in Vientiane, Lao
# REF : Thực trạng kiến thức và thực hành của người có thẻ bảo hiểm y tế trong sử dụng dịch vụ khám chữa bệnh ở các cơ sở y tế công và một số yếu tố ảnh hưởng tại tỉnh Viêng Chăn, CHDCND Lào, năm 2017
# PRED: in Vientiane, Lao
# assistant
# <think>
#
# </think>
#
# Kiến thức, thực hành sử dụng dịch vụ y tế công cộng của người dân có thẻ bảo hiểm y tế và các yếu tố ảnh hưởng tại thành phố Vientiane, Lào Cai
# --------------------------------------------------------------------------------
#
# [Test 2]
# EN  : Describe knowledge, practices in public health service utilization among health insurance card's holders and influencing factors in Vientiane, Lao PDR, 2017.
# REF : Mô tả thực trạng kiến thức, thực hành của người có thẻ bảo hiểm y tế trong sử dụng dịch vụ khám chữa bệnh ở các cơ sở y tế công và một số yếu tố liên quan tại tỉnh Viêng Chăn, Cộng hoà Dân chủ Nhân dân Lào năm 2017.
# PRED: assistant
# <think>
#
# </think>
#
# Mô tả kiến thức, thực hành sử dụng dịch vụ y tế công cộng của người dân có thẻ bảo hiểm y tế và các yếu tố ảnh hưởng tại thành phố Vientiane, Lào PDR, 2017.
# --------------------------------------------------------------------------------
#
# [Test 3]
# EN  : Methodology: A cross sectional study was used among 928 adult health insurance card's holders in Phone Hong and Keo Oudom districts, Vientiane province.
# REF : Phương pháp: Thiết kế nghiên mô tả cắt ngang được thực hiện trên 928 người trưởng thành có thẻ bảo hiểm y tế tại 2 huyện Phone Hong và Keo Oudom, tỉnh Viêng Chăn.
# PRED: <think>
#
# </think>
#
# Phương pháp: Nghiên cứu cắt ngang mô tả trên 928 người dân có thẻ BHYT tại huyện Phố Huế và huyện Khoái Châu, tỉnh Vĩnh Phúc.
# --------------------------------------------------------------------------------
# Downloading builder script: 0.00B [00:00, ?B/s]
# ============================================================
# KẾT QUẢ SACREBLEU
# ============================================================
# SacreBLEU score: 26.57
# Chi tiết: {'score': 26.56526305252884, 'counts': [67956, 46615, 32928, 23897], 'totals': [154110, 151110, 148110, 145110], 'precisions': [44.095775744598015, 30.848388591092583, 22.232124772128824, 16.46819654055544], 'bp': 1.0, 'sys_len': 154110, 'ref_len': 100870}

# %%
# ============================================================================
# CELL 9: Lưu kết quả inference ra file
# ============================================================================

import pandas as pd

# 1) Lưu bảng đầy đủ: câu EN, REF VI (nếu có), PRED VI
output_data = {
    "en": test_english,      # Câu nguồn tiếng Anh
    "pred_vi": predictions,  # Model dịch ra tiếng Việt
}
if has_reference:
    output_data["ref_vi"] = references  # Reference tiếng Việt (nếu có)

results_dataframe = pd.DataFrame(output_data)

os.makedirs(SAVE_DIR, exist_ok=True)

# Lưu CSV
csv_output_path = os.path.join(SAVE_DIR, "public_test_en-vi_predictions.csv")
results_dataframe.to_csv(csv_output_path, index=False, encoding="utf-8")
print(f"\n✓ Đã lưu bảng chi tiết vào: {csv_output_path}")

# 2) Lưu file predictions riêng (.txt) - mỗi dòng là một câu dịch
predictions_file = os.path.join(SAVE_DIR, "public_test.pred.vi.txt")
with open(predictions_file, "w", encoding="utf-8") as f:
    for pred_line in predictions:
        f.write(pred_line + "\n")
print(f"✓ Đã lưu file predictions vào: {predictions_file}")

print("\n" + "="*60)
print("HOÀN TẤT")
print("="*60)
# Out:
# ✓ Đã lưu bảng chi tiết vào: qwen3-1_7b-en-vi-mt/public_test_en-vi_predictions.csv
# ✓ Đã lưu file predictions vào: qwen3-1_7b-en-vi-mt/public_test.pred.vi.txt
#
# ============================================================
# HOÀN TẤT
# ============================================================
